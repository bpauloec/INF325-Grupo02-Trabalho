# %%
#Execução do Banco de Dados Cassandra - Reclamações

# %%
! pip install cassandra-driver
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 26.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 19.5 MB/s eta 0:00:00
# ...

# %%
! python3 insertDataComplaint.py
# Out:
# Success! Data inserted
